# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasRobles2323/Lab-2-I.A./blob/main/Entrega_Inteligencia_Artificial_Laboratorio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nombre   -   Rut   -   Malla
#
# #Gerald Espinoza   -  21.085.069-4   -   Malla Nueva
#
# #Ignacio Cortés   -   20.025.137-7   -   Malla Antigua
#
# #Lucas Robles   -   21.365.017-3   -   Malla Nueva
